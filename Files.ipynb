# %%
# Avoid this format to prevent file from closing in case of any errors
# f = open('test.txt', 'r')
# print(f.readline())
# f.close()

# %%
with open("multiLine.txt", 'r') as f:
    print(f.readline())
# Out:
# Hello

# %%
with open("multiLine.txt", 'r') as f:
    print(f.readline())
    print(f.readline())
    print(f.readline())
    print(f.readline())
    print(f.readline())
# Out:
# Hello
#
# World
#
# for
#
# Python
#
# course

# %%
with open("multiLine.txt", 'r') as f:
    print(f.readlines())
# Out:
# ['Hello\n', 'World\n', 'for\n', 'Python\n', 'course']

# %%
with open("multiLine.txt", 'r') as f:
    for line in f.readlines():
        print(line)
# Out:
# Hello
#
# World
#
# for
#
# Python
#
# course

# %%
# 'w' overwrites, 'a' appends

with open("multiLine.txt", 'a') as f:
    f.write("Yet Another Line\n")
    
# with open("multiLine.txt", 'a+') as f:
#     f.write("Yet Another Line\n")

# %%
with open("multiLine.txt", 'r') as f:
    for line in f.readlines():
        print(line)
# Out:
# Hello
#
# World
#
# for
#
# Python
#
# courseYet Another Line

# %%
with open("numbers.txt", 'w') as f:
    for i in range(12,20):
        f.write("Hello from number {} \n".format(i))

# %%
import sys
print("testerr", file=sys.stderr)
print("testout", file=sys.stdout)
# Out:
# testout
# testerr

# %%
with open("japanese.txt", 'r', encoding='utf-8') as f:
    for line in f.readlines():
        print(line)
# Out:
# とる  取 執 捕 採 摂 撮 盗 穫 録
#
#
#
# 穫る [とる] /(v5r,vt) (See 採る・2) to harvest (a crop)
#
# 採る [とる] /(v5r,vt) (1) to adopt (measure, proposal)/(2) to pick (e.g. fruit)/to catch (e.g. insects)/to take (e.g. a sample)/(3) to assume (attitude)/(4) to take on (i.e. hire)/to engage/(P)
#
# 撮る(P);録る [とる] /(v5r,vt) (1) (esp. 撮る) to take (a photo)/(2) (esp. 録る) to record (video, audio, etc.)/to make (a film)/(P)
#
# 執る [とる] /(v5r,vt) to take (trouble)/to attend (to business)/to command (army)/(P)
#
# 取る [とる] /(v5r,vt) (1) to take/to pick up/to harvest/to earn/to choose/(2) (See 盗る) to steal/(3) (See 摂る) to eat/to have (a meal)/(4) (also written as 脱る) to remove (one's glasses, etc.)/(5) to compete (in sumo, cards, etc.)/to play/(P)
#
# 摂る [とる] /(v5r,vt) (See 取る・3) to have (lunch, etc.)/to take (vitamins, etc.)
#
# 盗る [とる] /(v5r,vt) (See 取る・2) to take (nuance of stealing)
#
# 捕る(P) [とる] /(v5r,vt) to take/to catch (fish)/to capture/(P)
#
#
#
# ...

# %%
with open("emoji-data.txt", 'r', encoding='utf-8') as f:
    for line in f.readlines():
        print(line)
# Out:
# # Emoji Data for UTR #51
#
# #
#
# # File:    emoji-data.txt
#
# # Version: 1.0
#
# # Date:    2015-08-04
#
# #
#
# # Copyright (c) 2015 Unicode, Inc.
#
# # For terms of use, see http://www.unicode.org/terms_of_use.html
#
# # For documentation and usage, see http://www.unicode.org/reports/tr51/
#
# #
#
# # Format: Code ; Default_Emoji_Style ; Emoji_Level ; Emoji_Modifier_Status ; Emoji_Sources # Comment
#
# #
#
# #   Field 1 — Default_Emoji_Style:
#
# #             text:      default text presentation
#
# #             emoji:     default emoji presentation
#
# #   Field 2 — Emoji_Level:
#
# #             L1:        level 1 emoji
#
# #             L2:        level 2 emoji
#
# #             NA:        not applicable
#
# #   Field 3 — Emoji_Modifier_Status:
#
# #             modifier:  an emoji modifier
#
# #             primary:   a primary emoji modifier base
#
# #             secondary: a secondary emoji modifier base
#
# #             none:      not applicable
#
# ...
